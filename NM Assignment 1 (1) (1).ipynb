# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.shape
# Out:
# (14620, 23)

# %%
df = pd.read_csv('C:/Users/RAVIBHARATHI/Downloads/archive (1)/House Price India.csv')
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
df.size
# Out:
# 336260

# %%
df.median()
# Out:
# id                                       6.762821e+09
# Date                                     4.260000e+04
# number of bedrooms                       3.000000e+00
# number of bathrooms                      2.250000e+00
# living area                              1.930000e+03
# lot area                                 7.620000e+03
# number of floors                         1.500000e+00
# waterfront present                       0.000000e+00
# number of views                          0.000000e+00
# condition of the house                   3.000000e+00
# grade of the house                       7.000000e+00
# Area of the house(excluding basement)    1.580000e+03
# Area of the basement                     0.000000e+00
# Built Year                               1.975000e+03
# Renovation Year                          0.000000e+00
# Postal Code                              1.220320e+05
# Lattitude                                5.280640e+01
# ...

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
df.tail()
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 14615  6762830250  42734                   2                  1.5
# 14616  6762830339  42734                   3                  2.0
# 14617  6762830618  42734                   2                  1.0
# 14618  6762830709  42734                   4                  1.0
# 14619  6762831463  42734                   3                  1.0
#
#        living area  lot area  number of floors  waterfront present  \
# 14615         1556     20000               1.0                   0
# 14616         1680      7000               1.5                   0
# 14617         1070      6120               1.0                   0
# 14618         1030      6621               1.0                   0
# 14619          900      4770               1.0                   0
#
#        number of views  condition of the house  ...  Built Year  \
# 14615                0                       4  ...        1957
# ...

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.std()
# Out:
# id                                         6237.574799
# Date                                         67.347991
# number of bedrooms                            0.938719
# number of bathrooms                           0.769934
# living area                                 928.275721
# lot area                                  37919.621304
# number of floors                              0.540239
# waterfront present                            0.087193
# number of views                               0.766259
# condition of the house                        0.664151
# grade of the house                            1.175033
# Area of the house(excluding basement)       833.809963
# Area of the basement                        448.551409
# Built Year                                   29.493625
# Renovation Year                             416.216661
# Postal Code                                  19.082418
# Lattitude                                     0.137522
# ...

# %%
df.sum(1)
# Out:
# 0        6.765381e+09
# 1        6.764393e+09
# 2        6.764202e+09
# 3        6.763913e+09
# 4        6.763801e+09
#              ...
# 14615    6.763261e+09
# 14616    6.763236e+09
# 14617    6.763222e+09
# 14618    6.763219e+09
# 14619    6.763157e+09
# Length: 14620, dtype: float64

# %%
df.mode()
# Out:
#                id     Date  number of bedrooms  number of bathrooms  \
# 0      6762810020  42543.0                 3.0                  2.5
# 1      6762810021      NaN                 NaN                  NaN
# 2      6762810022      NaN                 NaN                  NaN
# 3      6762810023      NaN                 NaN                  NaN
# 4      6762810026      NaN                 NaN                  NaN
# ...           ...      ...                 ...                  ...
# 14615  6762831611      NaN                 NaN                  NaN
# 14616  6762831612      NaN                 NaN                  NaN
# 14617  6762831613      NaN                 NaN                  NaN
# 14618  6762831615      NaN                 NaN                  NaN
# 14619  6762831616      NaN                 NaN                  NaN
#
#        living area  lot area  number of floors  waterfront present  \
# 0           1400.0    5000.0               1.0                 0.0
# ...

# %%
df.mode()
# Out:
#                id     Date  number of bedrooms  number of bathrooms  \
# 0      6762810020  42543.0                 3.0                  2.5
# 1      6762810021      NaN                 NaN                  NaN
# 2      6762810022      NaN                 NaN                  NaN
# 3      6762810023      NaN                 NaN                  NaN
# 4      6762810026      NaN                 NaN                  NaN
# ...           ...      ...                 ...                  ...
# 14615  6762831611      NaN                 NaN                  NaN
# 14616  6762831612      NaN                 NaN                  NaN
# 14617  6762831613      NaN                 NaN                  NaN
# 14618  6762831615      NaN                 NaN                  NaN
# 14619  6762831616      NaN                 NaN                  NaN
#
#        living area  lot area  number of floors  waterfront present  \
# 0           1400.0    5000.0               1.0                 0.0
# ...

# %%
df.min()
# Out:
# id                                       6.762810e+09
# Date                                     4.249100e+04
# number of bedrooms                       1.000000e+00
# number of bathrooms                      5.000000e-01
# living area                              3.700000e+02
# lot area                                 5.200000e+02
# number of floors                         1.000000e+00
# waterfront present                       0.000000e+00
# number of views                          0.000000e+00
# condition of the house                   1.000000e+00
# grade of the house                       4.000000e+00
# Area of the house(excluding basement)    3.700000e+02
# Area of the basement                     0.000000e+00
# Built Year                               1.900000e+03
# Renovation Year                          0.000000e+00
# Postal Code                              1.220030e+05
# Lattitude                                5.238590e+01
# ...

# %%
df.max()
# Out:
# id                                       6.762832e+09
# Date                                     4.273400e+04
# number of bedrooms                       3.300000e+01
# number of bathrooms                      8.000000e+00
# living area                              1.354000e+04
# lot area                                 1.074218e+06
# number of floors                         3.500000e+00
# waterfront present                       1.000000e+00
# number of views                          4.000000e+00
# condition of the house                   5.000000e+00
# grade of the house                       1.300000e+01
# Area of the house(excluding basement)    9.410000e+03
# Area of the basement                     4.820000e+03
# Built Year                               2.015000e+03
# Renovation Year                          2.015000e+03
# Postal Code                              1.220720e+05
# Lattitude                                5.300760e+01
# ...

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
df.idxmin()
# Out:
# id                                       10503
# Date                                         0
# number of bedrooms                         324
# number of bathrooms                       7058
# living area                               4048
# lot area                                 11107
# number of floors                             5
# waterfront present                           0
# number of views                              1
# condition of the house                     242
# grade of the house                        1382
# Area of the house(excluding basement)     4048
# Area of the basement                         2
# Built Year                                  73
# Renovation Year                              0
# Postal Code                                  0
# Lattitude                                 3450
# Longitude                                13366
# living_area_renov                         2765
# lot_area_renov                            9936
# ...

# %%
df.idxmax()
# Out:
# id                                         242
# Date                                     14575
# number of bedrooms                        3532
# number of bathrooms                         76
# living area                                 76
# lot area                                  1146
# number of floors                          3547
# waterfront present                         342
# number of views                              0
# condition of the house                       0
# grade of the house                        2425
# Area of the house(excluding basement)       76
# Area of the basement                      2794
# Built Year                                1044
# Renovation Year                           1221
# Postal Code                                743
# Lattitude                                10625
# Longitude                                 4565
# living_area_renov                        13861
# lot_area_renov                           12058
# ...

# %%
df.mean()
# Out:
# id                                       6.762821e+09
# Date                                     4.260454e+04
# number of bedrooms                       3.379343e+00
# number of bathrooms                      2.129583e+00
# living area                              2.098263e+03
# lot area                                 1.509328e+04
# number of floors                         1.502360e+00
# waterfront present                       7.660739e-03
# number of views                          2.331053e-01
# condition of the house                   3.430506e+00
# grade of the house                       7.682421e+00
# Area of the house(excluding basement)    1.801784e+03
# Area of the basement                     2.964791e+02
# Built Year                               1.970926e+03
# Renovation Year                          9.092401e+01
# Postal Code                              1.220331e+05
# Lattitude                                5.279285e+01
# ...

# %%
df.median()
# Out:
# id                                       6.762821e+09
# Date                                     4.260000e+04
# number of bedrooms                       3.000000e+00
# number of bathrooms                      2.250000e+00
# living area                              1.930000e+03
# lot area                                 7.620000e+03
# number of floors                         1.500000e+00
# waterfront present                       0.000000e+00
# number of views                          0.000000e+00
# condition of the house                   3.000000e+00
# grade of the house                       7.000000e+00
# Area of the house(excluding basement)    1.580000e+03
# Area of the basement                     0.000000e+00
# Built Year                               1.975000e+03
# Renovation Year                          0.000000e+00
# Postal Code                              1.220320e+05
# Lattitude                                5.280640e+01
# ...

# %%
df.abs()
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
df.dtypes
# Out:
# id                                         int64
# Date                                       int64
# number of bedrooms                         int64
# number of bathrooms                      float64
# living area                                int64
# lot area                                   int64
# number of floors                         float64
# waterfront present                         int64
# number of views                            int64
# condition of the house                     int64
# grade of the house                         int64
# Area of the house(excluding basement)      int64
# Area of the basement                       int64
# Built Year                                 int64
# Renovation Year                            int64
# Postal Code                                int64
# Lattitude                                float64
# Longitude                                float64
# living_area_renov                          int64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.scatter(df.index,df['living area'])
plt.show()

# %%
sns.scatterplot(x=df.index, y=df['living area'], hue=df['lot area'])
# Out:
# <AxesSubplot:ylabel='living area'>

# %%
sns.histplot(df['Built Year'])
# Out:
# <AxesSubplot:xlabel='Built Year', ylabel='Count'>

# %%
sns.stripplot(x=df['living area'])
# Out:
# <AxesSubplot:xlabel='living area'>

# %%
df = pd.read_csv('F:/Dataset/House Price India.csv')

# %%
sns.displot(df['lot area'],kde=False,color='black',bins=10)

# %%
plt.figure(figsize=(5,5))
df['id'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.boxplot(df['lot area'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21ad05ea290>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21ad05ea7d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21ad05e9ff0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21ad05ead10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21ad05eafb0>],
#  'means': []}

# %%
sns.set(rc={'figure.figsize':(6,6)})
sns.displot(df['id'],color='black',rug=True)

# %%
plt.pie(df['id'])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15, 5))
sns.barplot(x=df['id'], y=df['living area'])
plt.xticks(rotation='vertical')
plt.show()

# %%
from sklearn import datasets, decomposition
iris = datasets.load_iris()
X = iris.data
y = iris.target
pca = decomposition.PCA(n_components=2)
X = pca.fit_transform(X)
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from scipy import stats

# %%
pd.plotting.scatter_matrix(df.loc[:, "id":"living area"], diagonal="kde",figsize=(20,15))
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("House Price India.csv")
df
